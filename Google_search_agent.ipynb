# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

search = GoogleSerperAPIWrapper()
llm= ChatGroq( model="openai/gpt-oss-20b")

agent= create_agent(
    model=llm,
    tools=[ search.run],
    system_prompt=" You are an agent and can search for any question on google"
)

# %%
question= "who was the winner of 2025 womens world cup"
res= agent.invoke({ "messages": [{"role":"user",
                                  "content": question}]})

print( res["messages"][-1].content)
# Out:
# The **India women's cricket team** won the **2025 ICC Women’s Cricket World Cup**. They defeated South Africa in the final, clinching their first-ever title.
